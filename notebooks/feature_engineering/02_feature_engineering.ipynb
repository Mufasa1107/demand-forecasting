# %% [markdown]
# # Feature Engineering
#
# This notebook builds lagged and calendar features for the demand forecasting models.

# %%
import pandas as pd

from src.data.generate_dummy_data import generate_sales_dataset
from src.features.build_features import build_feature_frame

df = generate_sales_dataset(regions=['North'], stores_per_region=1, categories_per_store=1, skus_per_category=2, periods=90, seed=7)
features = build_feature_frame(df, horizon=7)
print(features.head())
